# %% [markdown]
# # Model Training

# %%
# !pip install dask-ml
# Out:
# Requirement already satisfied: dask-ml in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /conda/lib/python3.6/site-packages (from dask-ml) (1.17.4)
# Requirement already satisfied: dask-glm>=0.2.0 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from dask-ml) (0.2.0)
# Requirement already satisfied: distributed>=2.4.0 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from dask-ml) (2.9.1)
# Requirement already satisfied: packaging in /conda/lib/python3.6/site-packages (from dask-ml) (19.2)
# Requirement already satisfied: scikit-learn>=0.21 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from dask-ml) (0.22.1)
# Requirement already satisfied: dask[array,dataframe]>=2.4.0 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from dask-ml) (2.9.1)
# Requirement already satisfied: multipledispatch>=0.4.9 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from dask-ml) (0.6.0)
# Requirement already satisfied: pandas>=0.23.4 in /conda/lib/python3.6/site-packages (from dask-ml) (0.24.2)
# Requirement already satisfied: scipy in /conda/lib/python3.6/site-packages (from dask-ml) (1.3.2)
# Requirement already satisfied: numba in /conda/lib/python3.6/site-packages (from dask-ml) (0.41.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from dask-glm>=0.2.0->dask-ml) (1.1.1)
# Requirement already satisfied: zict>=0.1.3 in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (1.0.0)
# Requirement already satisfied: tblib in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (1.6.0)
# Requirement already satisfied: setuptools in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (42.0.2.post20191203)
# Requirement already satisfied: psutil>=5.0 in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (5.6.7)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (2.1.0)
# Requirement already satisfied: msgpack in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (0.6.2)
# Requirement already satisfied: tornado>=5 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (5.1.1)
# Requirement already satisfied: click>=6.6 in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (7.0)
# Requirement already satisfied: toolz>=0.7.4 in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (0.10.0)
# Requirement already satisfied: pyyaml in /conda/lib/python3.6/site-packages (from distributed>=2.4.0->dask-ml) (5.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /conda/lib/python3.6/site-packages (from packaging->dask-ml) (2.4.5)
# Requirement already satisfied: six in /conda/lib/python3.6/site-packages (from packaging->dask-ml) (1.13.0)
# Requirement already satisfied: joblib>=0.11 in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from scikit-learn>=0.21->dask-ml) (0.14.1)
# Requirement already satisfied: fsspec>=0.6.0; extra == "dataframe" in /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (0.6.2)
# Requirement already satisfied: partd>=0.3.10; extra == "dataframe" in /conda/lib/python3.6/site-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (1.1.0)
# Requirement already satisfied: pytz>=2011k in /conda/lib/python3.6/site-packages (from pandas>=0.23.4->dask-ml) (2019.3)
# Requirement already satisfied: python-dateutil>=2.5.0 in /conda/lib/python3.6/site-packages (from pandas>=0.23.4->dask-ml) (2.8.1)
# Requirement already satisfied: llvmlite>=0.26.0dev0 in /conda/lib/python3.6/site-packages (from numba->dask-ml) (0.26.0)
# Requirement already satisfied: heapdict in /conda/lib/python3.6/site-packages (from zict>=0.1.3->distributed>=2.4.0->dask-ml) (1.0.1)
# Requirement already satisfied: locket in /conda/lib/python3.6/site-packages (from partd>=0.3.10; extra == "dataframe"->dask[array,dataframe]>=2.4.0->dask-ml) (0.2.0)

# %%
import scipy as sp
import numpy as np
import pandas as pd
import pickle
import os
import sys
sys.path.append('../../')
import v3io_frames_local as v3f
import dask.dataframe as dd
from dask.distributed import Client, progress

import matplotlib.pyplot as plt; plt.rcdefaults()
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.layouts import column, row, gridplot
from bokeh.models import ColumnDataSource

import dask_ml.model_selection as dcv
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline

import pprint

# %%
output_notebook()
pp = pprint.PrettyPrinter(indent=4)
client = v3f.Client('framesd:8081')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="daaa7007-ffe2-493e-ae49-3a3619c34c76">Loading BokehJS ...</span>
#     </div>

# %%
dask_client = Client()
# Out:
# /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages/bokeh/themes/theme.py:94: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   json = yaml.load(f)
# /User/.pythonlibs/jupyter-notebook/lib/python3.6/site-packages/distributed/dashboard/core.py:72: UserWarning:
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the diagnostics dashboard on a random port instead.
#   warnings.warn("\n" + msg)

# %% [markdown]
# ## Load data

# %%
df = dd.from_pandas(client.read(backend='tsdb', query='select * from netops_metrics_jupyter',
            start="now-1d", end='now+1d', multi_index=True).reset_index(), npartitions=4)
df.head(5)
# Out:
#                      time data_center         device      company  \
# 0 2020-01-10 18:30:34.637  John_Curve  7026488238274  Roberts_PLC
# 1 2020-01-10 18:30:39.637  John_Curve  7026488238274  Roberts_PLC
# 2 2020-01-10 18:30:44.637  John_Curve  7026488238274  Roberts_PLC
# 3 2020-01-10 18:30:49.637  John_Curve  7026488238274  Roberts_PLC
# 4 2020-01-10 18:30:54.637  John_Curve  7026488238274  Roberts_PLC
#
#    cpu_utilization  packet_loss_is_error  is_error  throughput_is_error  \
# 0        88.484602                   0.0       0.0                  0.0
# 1        65.315625                   0.0       0.0                  0.0
# 2        85.228517                   0.0       0.0                  0.0
# 3        75.384545                   0.0       0.0                  0.0
# 4        63.015509                   0.0       0.0                  0.0
#
#    throughput  cpu_utilization_is_error   latency  latency_is_error  \
# 0  223.201614                       0.0  2.354705               0.0
# 1  238.413831                       0.0  0.638181               0.0
# 2  272.113396                       0.0  0.000000               0.0
# 3  284.499619                       0.0  0.000000               0.0
# 4  239.421695                       0.0  0.000000               0.0
#
#    packet_loss
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     1.415631

# %%
df['key'] = df.apply(lambda row: f'{row["company"]}_{row["data_center"]}_{row["device"]}', axis=1, meta=df.compute().dtypes)
df.set_index('key')
df.head(10)
#df.sort_values('timestamp', ascending=True, inplace=True)
# Out:
#                      time data_center         device      company  \
# 0 2020-01-10 18:30:34.637  John_Curve  7026488238274  Roberts_PLC
# 1 2020-01-10 18:30:39.637  John_Curve  7026488238274  Roberts_PLC
# 2 2020-01-10 18:30:44.637  John_Curve  7026488238274  Roberts_PLC
# 3 2020-01-10 18:30:49.637  John_Curve  7026488238274  Roberts_PLC
# 4 2020-01-10 18:30:54.637  John_Curve  7026488238274  Roberts_PLC
# 5 2020-01-10 18:30:59.637  John_Curve  7026488238274  Roberts_PLC
# 6 2020-01-10 18:31:04.637  John_Curve  7026488238274  Roberts_PLC
# 7 2020-01-10 18:31:09.637  John_Curve  7026488238274  Roberts_PLC
# 8 2020-01-10 18:31:14.637  John_Curve  7026488238274  Roberts_PLC
# 9 2020-01-10 18:31:19.637  John_Curve  7026488238274  Roberts_PLC
#
#    cpu_utilization  packet_loss_is_error  is_error  throughput_is_error  \
# 0        88.484602                   0.0       0.0                  0.0
# 1        65.315625                   0.0       0.0                  0.0
# 2        85.228517                   0.0       0.0                  0.0
# 3        75.384545                   0.0       0.0                  0.0
# 4        63.015509                   0.0       0.0                  0.0
# 5        78.258995                   0.0       0.0                  0.0
# 6        62.552714                   0.0       0.0                  0.0
# 7        68.960976                   0.0       0.0                  0.0
# 8        65.545961                   0.0       0.0                  0.0
# 9        63.707748                   0.0       0.0                  0.0
#
#    throughput  cpu_utilization_is_error    latency  latency_is_error  \
# 0  223.201614                       0.0   2.354705               0.0
# 1  238.413831                       0.0   0.638181               0.0
# 2  272.113396                       0.0   0.000000               0.0
# 3  284.499619                       0.0   0.000000               0.0
# 4  239.421695                       0.0   0.000000               0.0
# 5  244.586052                       0.0  10.545494               0.0
# 6  229.478398                       0.0   0.000000               0.0
# 7  253.682738                       0.0   0.000000               0.0
# 8  241.973549                       0.0   3.768121               0.0
# 9  223.357996                       0.0   0.000000               0.0
#
#    packet_loss                                   key
# 0     0.000000  Roberts_PLC_John_Curve_7026488238274
# 1     0.000000  Roberts_PLC_John_Curve_7026488238274
# 2     0.000000  Roberts_PLC_John_Curve_7026488238274
# 3     0.000000  Roberts_PLC_John_Curve_7026488238274
# 4     1.415631  Roberts_PLC_John_Curve_7026488238274
# 5     0.064035  Roberts_PLC_John_Curve_7026488238274
# 6     4.073991  Roberts_PLC_John_Curve_7026488238274
# 7     0.822157  Roberts_PLC_John_Curve_7026488238274
# 8     0.796025  Roberts_PLC_John_Curve_7026488238274
# 9     0.000000  Roberts_PLC_John_Curve_7026488238274

# %%
df["cpu_1h_mean"] = df.cpu_utilization.rolling(window=12).mean()
df["latency_1h_mean"] = df.latency.rolling(window=12).mean()
df["packet_loss_1h_mean"] = df.packet_loss.rolling(window=12).mean()
df["throughput_1h_mean"] = df.throughput.rolling(window=12).mean()

df.head(10)
# Out:
#                      time data_center         device      company  \
# 0 2020-01-10 18:30:34.637  John_Curve  7026488238274  Roberts_PLC
# 1 2020-01-10 18:30:39.637  John_Curve  7026488238274  Roberts_PLC
# 2 2020-01-10 18:30:44.637  John_Curve  7026488238274  Roberts_PLC
# 3 2020-01-10 18:30:49.637  John_Curve  7026488238274  Roberts_PLC
# 4 2020-01-10 18:30:54.637  John_Curve  7026488238274  Roberts_PLC
# 5 2020-01-10 18:30:59.637  John_Curve  7026488238274  Roberts_PLC
# 6 2020-01-10 18:31:04.637  John_Curve  7026488238274  Roberts_PLC
# 7 2020-01-10 18:31:09.637  John_Curve  7026488238274  Roberts_PLC
# 8 2020-01-10 18:31:14.637  John_Curve  7026488238274  Roberts_PLC
# 9 2020-01-10 18:31:19.637  John_Curve  7026488238274  Roberts_PLC
#
#    cpu_utilization  packet_loss_is_error  is_error  throughput_is_error  \
# 0        88.484602                   0.0       0.0                  0.0
# 1        65.315625                   0.0       0.0                  0.0
# 2        85.228517                   0.0       0.0                  0.0
# 3        75.384545                   0.0       0.0                  0.0
# 4        63.015509                   0.0       0.0                  0.0
# 5        78.258995                   0.0       0.0                  0.0
# 6        62.552714                   0.0       0.0                  0.0
# 7        68.960976                   0.0       0.0                  0.0
# 8        65.545961                   0.0       0.0                  0.0
# 9        63.707748                   0.0       0.0                  0.0
#
#    throughput  cpu_utilization_is_error    latency  latency_is_error  \
# 0  223.201614                       0.0   2.354705               0.0
# 1  238.413831                       0.0   0.638181               0.0
# 2  272.113396                       0.0   0.000000               0.0
# 3  284.499619                       0.0   0.000000               0.0
# 4  239.421695                       0.0   0.000000               0.0
# 5  244.586052                       0.0  10.545494               0.0
# 6  229.478398                       0.0   0.000000               0.0
# 7  253.682738                       0.0   0.000000               0.0
# 8  241.973549                       0.0   3.768121               0.0
# 9  223.357996                       0.0   0.000000               0.0
#
#    packet_loss                                   key  cpu_1h_mean  \
# 0     0.000000  Roberts_PLC_John_Curve_7026488238274          NaN
# 1     0.000000  Roberts_PLC_John_Curve_7026488238274          NaN
# 2     0.000000  Roberts_PLC_John_Curve_7026488238274          NaN
# 3     0.000000  Roberts_PLC_John_Curve_7026488238274          NaN
# 4     1.415631  Roberts_PLC_John_Curve_7026488238274          NaN
# 5     0.064035  Roberts_PLC_John_Curve_7026488238274          NaN
# 6     4.073991  Roberts_PLC_John_Curve_7026488238274          NaN
# 7     0.822157  Roberts_PLC_John_Curve_7026488238274          NaN
# 8     0.796025  Roberts_PLC_John_Curve_7026488238274          NaN
# 9     0.000000  Roberts_PLC_John_Curve_7026488238274          NaN
#
#    latency_1h_mean  packet_loss_1h_mean  throughput_1h_mean
# 0              NaN                  NaN                 NaN
# 1              NaN                  NaN                 NaN
# 2              NaN                  NaN                 NaN
# 3              NaN                  NaN                 NaN
# 4              NaN                  NaN                 NaN
# 5              NaN                  NaN                 NaN
# 6              NaN                  NaN                 NaN
# 7              NaN                  NaN                 NaN
# 8              NaN                  NaN                 NaN
# 9              NaN                  NaN                 NaN

# %%
# Drop first 'Window' samples due to no featuers
# (Don't want to confuse the ML algorithm)
feature_vectors = df.dropna()[['cpu_utilization', 'latency', 'packet_loss', 'throughput', 'cpu_1h_mean', 'latency_1h_mean', 'packet_loss_1h_mean', 'throughput_1h_mean', 'is_error']]
feature_vectors.head(10)
# Out:
#     cpu_utilization    latency  packet_loss  throughput  cpu_1h_mean  \
# 11        59.534368   0.752885     0.000000  254.303641    70.010186
# 12        63.926298   0.749091     0.000000  254.030072    67.963661
# 13        81.087116  13.068888     0.000000  233.671279    69.277952
# 14        76.480438   3.313845     1.322079  256.707807    68.548945
# 15        71.103633   0.000000     0.000000  202.725881    68.192202
# 16        85.370503   4.022155     0.000000  255.781661    70.055119
# 17        71.259090   0.000000     1.895075  263.233415    69.471793
# 18        87.812752   0.000000     1.736162  252.518276    71.576796
# 19        65.727765   0.000000     0.000000  244.129823    71.307362
# 20        63.760104   0.000000     1.373622  234.295685    71.158541
#
#     latency_1h_mean  packet_loss_1h_mean  throughput_1h_mean  is_error
# 11         1.700553             0.599096          244.865357       0.0
# 12         1.566752             0.599096          247.434395       0.0
# 13         2.602644             0.599096          247.039183       0.0
# 14         2.878798             0.709269          245.755383       0.0
# 15         2.878798             0.709269          238.940905       0.0
# 16         3.213977             0.591300          240.304236       0.0
# 17         2.335186             0.743887          241.858183       0.0
# 18         2.335186             0.549068          243.778172       0.0
# 19         2.335186             0.480555          242.982096       0.0
# 20         2.021176             0.528688          242.342274       0.0

# %%
from dask_ml.model_selection import train_test_split

# %% [markdown]
# ## Training

# %%
X = feature_vectors[['cpu_1h_mean', 'latency_1h_mean', 'packet_loss_1h_mean', 'throughput_1h_mean']]
y = feature_vectors['is_error']
X_train, X_test, y_train, y_test = dcv.train_test_split(X, y, train_size=0.7, test_size=0.3)

# %%
param_grid = {
    'n_estimators': [5, 10, 20, 30]
}

model = GradientBoostingClassifier()
model = dcv.GridSearchCV(model, param_grid)

print(X_train.compute().shape, y_train.compute().shape)

model.fit(X_train.compute(), y_train.compute())
# Out:
# (4033, 4) (4033,)
# GridSearchCV(cache_cv=True, cv=None, error_score='raise',
#              estimator=GradientBoostingClassifier(ccp_alpha=0.0,
#                                                   criterion='friedman_mse',
#                                                   init=None, learning_rate=0.1,
#                                                   loss='deviance', max_depth=3,
#                                                   max_features=None,
#                                                   max_leaf_nodes=None,
#                                                   min_impurity_decrease=0.0,
#                                                   min_impurity_split=None,
#                                                   min_samples_leaf=1,
#                                                   min_samples_split=2,
#                                                   min_weight_fraction_leaf=0.0,
#                                                   n_estimators=100,
#                                                   n_iter_no_change=None,
#                                                   presort='deprecated',
#                                                   random_state=None,
#                                                   subsample=1.0, tol=0.0001,
#                                                   validation_fraction=0.1,
#                                                   verbose=0, warm_start=False),
#              iid=True, n_jobs=-1, param_grid={'n_estimators': [5, 10, 20, 30]},
#              refit=True, return_train_score=False, scheduler=None,
#              scoring=None)

# %%
model.score(X_test, y_test)
# Out:
# 0.9918793503480279

# %%
model.best_estimator_
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=20,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
# !mkdir models
# Out:
# mkdir: cannot create directory ‘models’: File exists

# %%
version = '1.0'
model_filepath = 'models/netops.v{}.model'.format(version)
with open(model_filepath, 'wb+') as f:
    pickle.dump(model.best_estimator_, f)
